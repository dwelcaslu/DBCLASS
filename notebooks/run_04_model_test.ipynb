# %%
import sys
sys.path.append('../src/')

# %%
# Third-party libraries:
import numpy as np
# My libraries:
import dataset.dataset as dtset
from dbclass.dbclass import DBCLASS
from dbclass import dbclass_utils as db_utils

# %%
mean_array = np.array([[10, 10],
                        [5, 20],
                        [10, 30],
                        [50, 50],
                        [30, 20],
                        [50, 10]])
sigma_array = np.array([[2, 1],
                        [2, 3],
                        [6, 3],
                        [8, 4],
                        [8, 8],
                        [6, 7]])

# %%
# Creating the dataset:
ds = dtset.create_dataset(mean_array, sigma_array, n_samples=10000)
ds
# Out:
# {'data': array([[13.52810469, 10.08261103],
#         [10.80031442,  9.17846548],
#         [11.95747597, 10.0189221 ],
#         ...,
#         [51.2655363 , 26.75825972],
#         [51.05518233, 21.56937527],
#         [49.32033231, 24.12712685]]),
#  'target': array([0, 0, 0, ..., 5, 5, 5]),
#  'target_names': array(['Class 1', 'Class 2', 'Class 3', 'Class 4', 'Class 5', 'Class 6'],
#        dtype='<U7'),
#  'feature_names': array(['x1', 'x2'], dtype='<U2')}

# %%
# Once the best probability score threshold is found, the classifier is
# configured with the best settings:
dbclass = DBCLASS(prob_thold=0.5)
dbclass.fit(ds['data'], ds['target'])
db_utils.dbclass_model_test(dbclass, ds)
# Out:
# C:\Users\weldl\Miniconda3\envs\dbclass\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\dbclass\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\dbclass\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#      Class 1       1.00      0.84      0.92      1666
#      Class 2       0.98      0.83      0.90      1666
#      Class 3       0.92      0.84      0.88      1666
#      Class 4       1.00      0.86      0.92      1666
#      Class 5       0.88      0.83      0.86      1666
#      Class 6       0.95      0.82      0.88      1666
#      Unknown       0.00      0.00      0.00         0
#
#     accuracy                           0.84      9996
#    macro avg       0.82      0.72      0.76      9996
# weighted avg       0.96      0.84      0.89      9996
#
#
# Confusion matrix:
# [[1.408e+01 4.000e-02 0.000e+00 0.000e+00 0.000e+00 0.000e+00 2.550e+00]
#  [0.000e+00 1.386e+01 8.700e-01 0.000e+00 7.000e-02 0.000e+00 1.870e+00]
#  [0.000e+00 2.000e-01 1.398e+01 0.000e+00 7.100e-01 0.000e+00 1.780e+00]
#  [0.000e+00 0.000e+00 0.000e+00 1.426e+01 4.000e-02 0.000e+00 2.370e+00]
#  [2.000e-02 0.000e+00 4.000e-01 1.000e-02 1.384e+01 7.300e-01 1.670e+00]
#  [0.000e+00 0.000e+00 0.000e+00 0.000e+00 1.000e+00 1.372e+01 1.950e+00]
#  [0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00]]
#
# Index and Target label:
# Index: 0 Label: Class 1
# Index: 1 Label: Class 2
# Index: 2 Label: Class 3
# Index: 3 Label: Class 4
# Index: 4 Label: Class 5
# Index: 5 Label: Class 6
#
# Probability score threshold: 0.5
# accuracy 0.837233
# prob_score 0.764063
# rejection 0.121876
# confidence 0.800648
